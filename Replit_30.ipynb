# %%
name = "Aiman"
age = "28"
pronouns = "he/him"

print(f"Hi, my name is {name}, I'm {age} years old and my pronouns is {pronouns}.")
# Out:
# Hi, my name is Aiman, I'm 28 years old and my pronouns is he/him.

# %%
for i in range(1, 31):
  print(f"Day {i: ^4} of 30")

# %%
print("30 Days Down - What did you think?")
print()
for i in range(1, 31):
  thought = input(f"Day {i}:\n")
  print()
  myText = f"You thought Day {i} was"
  print(f"{myText:^35}")
  print(f"{thought:^35}")
  print()
# Out:
# 30 Days Down - What did you think?
#
#
#        You thought Day 1 was
#               Okayla
#
#
#        You thought Day 2 was
#                fuyo
#
#
#        You thought Day 3 was
#
#
#
#        You thought Day 4 was
#
#
#
#        You thought Day 5 was
#
#
#
#        You thought Day 6 was
#
#
#
#        You thought Day 7 was
#
#
#
#        You thought Day 8 was
#
#
#
#        You thought Day 9 was
#
#
#
#       You thought Day 10 was
#
#
#
#       You thought Day 11 was
#
#
#
#       You thought Day 12 was
#
#
#
#       You thought Day 13 was
#
#
#
#       You thought Day 14 was
#
#
#
#       You thought Day 15 was
#
#
#
#       You thought Day 16 was
#
#
#
#       You thought Day 17 was
#
#
#
#       You thought Day 18 was
#
#
#
#       You thought Day 19 was
#
#
#
#       You thought Day 20 was
#
#
#
#       You thought Day 21 was
#
#
#
#       You thought Day 22 was
#
#
#
#       You thought Day 23 was
#
#
#
#       You thought Day 24 was
#
#
#
# ...
